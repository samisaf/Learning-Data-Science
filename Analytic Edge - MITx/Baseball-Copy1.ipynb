# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 3.0.0     ✔ purrr   0.2.5
# ✔ tibble  1.4.2     ✔ dplyr   0.7.6
# ✔ tidyr   0.8.1     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
baseball = read.csv("./files/baseball.csv")
head(baseball)
# Out:
#   Team League Year RS  RA  W  OBP   SLG   BA    Playoffs RankSeason
# 1 ARI  NL     2012 734 688 81 0.328 0.418 0.259 0        NA
# 2 ATL  NL     2012 700 600 94 0.320 0.389 0.247 1         4
# 3 BAL  AL     2012 712 705 93 0.311 0.417 0.247 1         5
# 4 BOS  AL     2012 734 806 69 0.315 0.415 0.260 0        NA
# 5 CHC  NL     2012 613 759 61 0.302 0.378 0.240 0        NA
# 6 CHW  AL     2012 748 676 85 0.318 0.422 0.255 0        NA
#   RankPlayoffs G   OOBP  OSLG
# 1 NA           162 0.317 0.415
# 2  5           162 0.306 0.378
# 3  4           162 0.315 0.403
# 4 NA           162 0.331 0.428
# 5 NA           162 0.335 0.424
# 6 NA           162 0.319 0.405

# %%
# 3 ways of subsetting a dataframe
mb1 = subset(baseball, Year < 2002)
mb2 = baseball[baseball$Year < 2002, ]
mb3 = baseball %>% filter(Year < 2002)

# %%
mb2==mb3
# Out:
#      Team League Year RS   RA   W    OBP  SLG  BA   Playoffs RankSeason
# 331  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 332  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE     TRUE
# 333  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE     TRUE
# 334  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 335  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 336  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 337  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 338  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 339  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE     TRUE
# 340  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 341  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 342  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE       NA
# 343  TRUE TRUE   TRUE TRUE TRUE TRUE TRUE TRUE TRUE TRUE     TRUE
# ...
